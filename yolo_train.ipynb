# %%
# !pip install ultralytics

# %%
# !nvidia-smi

# %%
from google.colab import drive

drive.mount("/content/gdrive")

# %%
import os
import locale
locale.getpreferredencoding = lambda: "UTF-8"

from ultralytics import YOLO

# %%
ROOT_DIR = "/content/gdrive/My Drive/yolo"

# %%
model = YOLO(os.path.join(ROOT_DIR, "yolov9c.pt")) # Pretrained

# %%
results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"), epochs=100, imgsz=640)

# %%
# !scp -r /content/runs/detect/train "/content/gdrive/My Drive/yolo"
